# %% [markdown]
# <a href="https://colab.research.google.com/github/AlejandroGuedez/Equipo-23-de-Diplomado-data-scientist/blob/Versiones/NoSupervizado_Gr23_original.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis No Supervisado
# ### Grupo 23
#
# **Integrantes:** Franco Amilcar Genolet (francogeno97@gmail.com), Fabian Alejandro Zapata Cerutti (fzc501@gmail.com), Luis Alejandro Guedez Gomez (luis.guedez@dicsys.com), María Laura Mantovani (mantovanimlaura@gmail.com).

# %% [markdown]
# ###Práctico entregable:
#
# Utilizar la base de jugadores “players_22.csv” disponible en la [página de Kaggle](https://www.kaggle.com/datasets/stefanoleone992/fifa-22-complete-player-dataset). Considerar que la base 2022 no tiene el mismo formato que la base vista en clase, a los nombres de las variables se les agregó una keyword para identificar a qué tipo de habilidad corresponde.
#
# Con la nueva base, realizar un análisis análogo al que realizamos en el cursado de la materia con los datos FIFA2019. Realice comentarios en cada parte (verbose=True ;))
#
# 1- Análisis exploratorio de la base. **FRANCO**
#
# 2- Evaluación visual  e intuitiva de a dos variables numéricas por vez. **FRANCO**
#
# 3- Uso de dos técnicas de clustering: por ejemplo k-medias, DBSCAN, mezcla de Gaussianas y/o alguna jerárquica. Elección justificada de hiper-parámetros. **DBSCAN:LAU, DBSCAN:ALE**
#
# 4- Evaluación y Análisis de los clusters encontrados.** ALE-LAU-FRANCO**
#
# 5- Pregunta: ¿Se realizó alguna normalización o escalado de la base? ¿Por qué? **FABIAN**
#
# 6- Uso de alguna transformación (proyección, Embedding) para visualizar los resultados y/o usarla como preprocesado para aplicar alguna técnica de clustering. **FABIAN**

# %% [markdown]
# ## 1.-Inicialización-del-entorno

# %% [markdown]
# **Empezamos cargando algunas herramientas para cargar los datos y manipularlos.**

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',1000)
import itertools
import warnings
warnings.filterwarnings("ignore")
import io

# %% [markdown]
# **Para visualización usaremos principalmente plotly, también seaborn y matplotlib.**

# %%
from plotly.offline import init_notebook_mode, plot,iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
import matplotlib.pyplot as plt
import plotly.tools as tls#visualization
import plotly.figure_factory as ff#visualization
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## 2.-Exploración-de-la-base

# %%
df=pd.read_csv("players_22.csv")
df.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
#
#        short_name                       long_name player_positions  overall  \
# 0        L. Messi  Lionel Andrés Messi Cuccittini       RW, ST, CF       93
# 1  R. Lewandowski              Robert Lewandowski               ST       92
#
#    potential    value_eur  wage_eur  age         dob  height_cm  weight_kg  \
# 0         93   78000000.0  320000.0   34  1987-06-24        170         72
# 1         92  119500000.0  270000.0   32  1988-08-21        185         81
#
#    club_team_id            club_name           league_name  league_level  \
# 0          73.0  Paris Saint-Germain        French Ligue 1           1.0
# 1          21.0    FC Bayern München  German 1. Bundesliga           1.0
#
#   club_position  club_jersey_number club_loaned_from club_joined  \
# 0            RW                30.0              NaN  2021-08-10
# 1            ST                 9.0              NaN  2014-07-01
#
#    club_contract_valid_until  nationality_id nationality_name  nation_team_id  \
# 0                     2023.0              52        Argentina          1369.0
# 1                     2023.0              37           Poland          1353.0
#
#   nation_position  nation_jersey_number preferred_foot  weak_foot  \
# 0              RW                  10.0           Left          4
# 1              RS                   9.0          Right          4
#
#    skill_moves  international_reputation    work_rate body_type real_face  \
# 0            4                         5   Medium/Low    Unique       Yes
# 1            4                         5  High/Medium    Unique       Yes
#
#    release_clause_eur                                        player_tags  \
# 0         144300000.0  #Dribbler, #Distance Shooter, #FK Specialist, ...
# 1         197200000.0  #Aerial Threat, #Distance Shooter, #Clinical F...
#
#                                        player_traits  pace  shooting  passing  \
# 0  Finesse Shot, Long Shot Taker (AI), Playmaker ...  85.0      92.0     91.0
# 1  Solid Player, Finesse Shot, Outside Foot Shot,...  78.0      92.0     79.0
#
#    dribbling  defending  physic  attacking_crossing  attacking_finishing  \
# 0       95.0       34.0    65.0                  85                   95
# 1       86.0       44.0    82.0                  71                   95
#
#    attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                          70                       91                 88
# 1                          90                       85                 89
#
#    skill_dribbling  skill_curve  ...  power_stamina  power_strength  \
# 0               96           93  ...             72              69
# 1               85           79  ...             76              86
#
#    power_long_shots  mentality_aggression  mentality_interceptions  \
# 0                94                    44                       40
# 1                87                    81                       49
#
#    mentality_positioning  mentality_vision  mentality_penalties  \
# 0                     93                95                   75
# 1                     95                81                   90
#
#    mentality_composure  defending_marking_awareness  \
# 0                   96                           20
# 1                   88                           35
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         35                        24                   6
# 1                         42                        19                  15
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                     6                   12                        8
#
#    goalkeeping_reflexes  goalkeeping_speed    ls    st    rs  lw  lf  cf  rf  \
# 0                     8                NaN  89+3  89+3  89+3  92  93  93  93
# 1                    10                NaN  90+2  90+2  90+2  85  88  88  88
#
#    rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm  \
# 0  92    93    93    93  91+2  87+3  87+3  87+3  91+2  66+3  64+3  64+3  64+3
# 1  85  86+3  86+3  86+3  84+3  80+3  80+3  80+3  84+3  64+3  66+3  66+3  66+3
#
#     rwb    lb   lcb    cb   rcb    rb    gk  \
# 0  66+3  61+3  50+3  50+3  50+3  61+3  19+3
# 1  64+3  61+3  60+3  60+3  60+3  61+3  19+3
#
#                                      player_face_url  \
# 0  https://cdn.sofifa.net/players/158/023/22_120.png
# 1  https://cdn.sofifa.net/players/188/545/22_120.png
#
#                             club_logo_url  \
# 0  https://cdn.sofifa.net/teams/73/60.png
# 1  https://cdn.sofifa.net/teams/21/60.png
#
#                          club_flag_url  \
# 0  https://cdn.sofifa.net/flags/fr.png
# 1  https://cdn.sofifa.net/flags/de.png
#
#                             nation_logo_url  \
# 0  https://cdn.sofifa.net/teams/1369/60.png
# 1  https://cdn.sofifa.net/teams/1353/60.png
#
#                        nation_flag_url
# 0  https://cdn.sofifa.net/flags/ar.png
# 1  https://cdn.sofifa.net/flags/pl.png
#
# [2 rows x 110 columns]

# %%
df.tail(4)
# Out:
#        sofifa_id                                         player_url  \
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name                long_name player_positions  overall  \
# 19235           C. Porter          Caoimhin Porter               CM       47
# 19236            N. Logue  Nathan Logue-Cunningham               CM       47
# 19237           L. Rudden              Luke Rudden               ST       47
# 19238  E. Lalchhanchhuaha  Emanuel Lalchhanchhuaha              CAM       47
#
#        potential  value_eur  wage_eur  age         dob  height_cm  weight_kg  \
# 19235         59   110000.0     500.0   19  2002-03-18        175         70
# 19236         55   100000.0     500.0   21  2000-02-07        178         72
# 19237         60   110000.0     500.0   19  2002-04-23        173         66
# 19238         60   110000.0     500.0   19  2002-02-06        167         61
#
#        club_team_id            club_name                     league_name  \
# 19235         445.0           Derry City  Rep. Ireland Airtricity League
# 19236      111131.0           Finn Harps  Rep. Ireland Airtricity League
# 19237      111131.0           Finn Harps  Rep. Ireland Airtricity League
# 19238      113040.0  NorthEast United FC             Indian Super League
#
#        league_level club_position  club_jersey_number club_loaned_from  \
# 19235           1.0           RES                27.0              NaN
# 19236           1.0           RES                31.0              NaN
# 19237           1.0           RES                12.0              NaN
# 19238           1.0           SUB                13.0              NaN
#
#       club_joined  club_contract_valid_until  nationality_id  \
# 19235  2021-02-22                     2021.0              25
# 19236  2021-06-18                     2021.0              25
# 19237  2021-06-18                     2021.0              25
# 19238  2021-08-31                     2025.0             159
#
#           nationality_name  nation_team_id nation_position  \
# 19235  Republic of Ireland             NaN             NaN
# 19236  Republic of Ireland             NaN             NaN
# 19237  Republic of Ireland             NaN             NaN
# 19238                India             NaN             NaN
#
#        nation_jersey_number preferred_foot  weak_foot  skill_moves  \
# 19235                   NaN          Right          3            2
# 19236                   NaN          Right          3            2
# 19237                   NaN          Right          3            2
# 19238                   NaN          Right          3            2
#
#        international_reputation      work_rate       body_type real_face  \
# 19235                         1  Medium/Medium  Lean (170-185)        No
# 19236                         1  Medium/Medium  Lean (170-185)        No
# 19237                         1  Medium/Medium  Lean (170-185)        No
# 19238                         1  Medium/Medium     Lean (170-)        No
#
#        release_clause_eur player_tags player_traits  pace  shooting  passing  \
# 19235            193000.0         NaN           NaN  59.0      39.0     50.0
# 19236            175000.0         NaN           NaN  60.0      37.0     45.0
# 19237            239000.0         NaN           NaN  68.0      46.0     36.0
# 19238            217000.0         NaN           NaN  68.0      38.0     45.0
#
#        dribbling  defending  physic  attacking_crossing  attacking_finishing  \
# 19235       46.0       41.0    51.0                  54                   33
# 19236       49.0       41.0    52.0                  39                   32
# 19237       48.0       15.0    42.0                  29                   49
# 19238       48.0       36.0    48.0                  39                   32
#
#        attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 19235                          46                       51                 32
# 19236                          43                       49                 37
# 19237                          40                       38                 34
# 19238                          46                       50                 37
#
#        skill_dribbling  skill_curve  ...  power_stamina  power_strength  \
# 19235               41           53  ...             63              47
# 19236               47           37  ...             56              50
# 19237               42           36  ...             50              40
# 19238               48           38  ...             57              40
#
#        power_long_shots  mentality_aggression  mentality_interceptions  \
# 19235                38                    49                       39
# 19236                34                    51                       38
# 19237                41                    34                       14
# 19238                36                    55                       42
#
#        mentality_positioning  mentality_vision  mentality_penalties  \
# 19235                     51                49                   44
# 19236                     45                46                   39
# 19237                     47                40                   49
# 19238                     47                46                   35
#
#        mentality_composure  defending_marking_awareness  \
# 19235                   47                           37
# 19236                   36                           38
# 19237                   47                           10
# 19238                   36                           33
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 19235                         44                        47
# 19236                         44                        48
# 19237                         14                        11
# 19238                         31                        37
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 19235                  11                    12                    6
# 19236                   8                     6                    7
# 19237                   7                    10                    7
# 19238                   8                    13                   13
#
#        goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed    ls  \
# 19235                        8                    10                NaN  45+2
# 19236                       10                     6                NaN  45+2
# 19237                       14                    15                NaN  47+2
# 19238                        9                    14                NaN  45+2
#
#          st    rs  lw  lf  cf  rf  rw   lam   cam   ram    lm   lcm    cm  \
# 19235  45+2  45+2  47  46  46  46  47  47+2  47+2  47+2  49+2  47+2  47+2
# 19236  45+2  45+2  46  46  46  46  46  47+2  47+2  47+2  48+2  47+2  47+2
# 19237  47+2  47+2  47  47  47  47  47  45+2  45+2  45+2  45+2  39+2  39+2
# 19238  45+2  45+2  47  47  47  47  47  47+2  47+2  47+2  48+2  46+2  46+2
#
#         rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb  \
# 19235  47+2  49+2  49+2  46+2  46+2  46+2  49+2  48+2  44+2  44+2  44+2  48+2
# 19236  47+2  48+2  47+2  46+2  46+2  46+2  47+2  47+2  45+2  45+2  45+2  47+2
# 19237  39+2  45+2  33+2  29+2  29+2  29+2  33+2  32+2  26+2  26+2  26+2  32+2
# 19238  46+2  48+2  45+2  44+2  44+2  44+2  45+2  45+2  41+2  41+2  41+2  45+2
#
#          gk                                    player_face_url  \
# 19235  14+2  https://cdn.sofifa.net/players/262/040/22_120.png
# 19236  12+2  https://cdn.sofifa.net/players/262/760/22_120.png
# 19237  15+2  https://cdn.sofifa.net/players/262/820/22_120.png
# 19238  16+2  https://cdn.sofifa.net/players/264/540/22_120.png
#
#                                     club_logo_url  \
# 19235     https://cdn.sofifa.net/teams/445/60.png
# 19236  https://cdn.sofifa.net/teams/111131/60.png
# 19237  https://cdn.sofifa.net/teams/111131/60.png
# 19238  https://cdn.sofifa.net/teams/113040/60.png
#
#                              club_flag_url nation_logo_url  \
# 19235  https://cdn.sofifa.net/flags/ie.png             NaN
# 19236  https://cdn.sofifa.net/flags/ie.png             NaN
# 19237  https://cdn.sofifa.net/flags/ie.png             NaN
# 19238  https://cdn.sofifa.net/flags/in.png             NaN
#
#                            nation_flag_url
# 19235  https://cdn.sofifa.net/flags/ie.png
# 19236  https://cdn.sofifa.net/flags/ie.png
# 19237  https://cdn.sofifa.net/flags/ie.png
# 19238  https://cdn.sofifa.net/flags/in.png
#
# [4 rows x 110 columns]

# %%
print(df.columns)
print(len(df.columns), 'variables')
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name',
#        'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'age',
#        ...
#        'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url',
#        'club_flag_url', 'nation_logo_url', 'nation_flag_url'],
#       dtype='object', length=110)
# 110 variables

# %%
print(df.describe())
# Out:
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   19239.000000  19239.000000  19239.000000  1.916500e+04   19178.000000
# mean   231468.086959     65.772182     71.079370  2.850452e+06    9017.989363
# std     27039.717497      6.880232      6.086213  7.613700e+06   19470.176724
# min        41.000000     47.000000     49.000000  9.000000e+03     500.000000
# 25%    214413.500000     61.000000     67.000000  4.750000e+05    1000.000000
# 50%    236543.000000     66.000000     71.000000  9.750000e+05    3000.000000
# 75%    253532.500000     70.000000     75.000000  2.000000e+06    8000.000000
# max    264640.000000     93.000000     95.000000  1.940000e+08  350000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  19239.000000  19239.000000  19239.000000   19178.000000  19178.000000
# mean      25.210822    181.299704     74.943032   50580.498123      1.354364
# std        4.748235      6.863179      7.069434   54401.868535      0.747865
# min       16.000000    155.000000     49.000000       1.000000      1.000000
# 25%       21.000000    176.000000     70.000000     479.000000      1.000000
# 50%       25.000000    181.000000     75.000000    1938.000000      1.000000
# 75%       29.000000    186.000000     80.000000  111139.000000      1.000000
# max       54.000000    206.000000    110.000000  115820.000000      5.000000
#
#        club_jersey_number  club_contract_valid_until  nationality_id  \
# count        19178.000000               19178.000000    19239.000000
# mean            20.945250                2022.764000       58.602682
# std             17.909369                   1.213203       50.298614
# min              1.000000                2021.000000        1.000000
# 25%              9.000000                2022.000000       21.000000
# 50%             18.000000                2022.000000       45.000000
# 75%             27.000000                2024.000000       60.000000
# max             99.000000                2031.000000      219.000000
#
#        nation_team_id  nation_jersey_number     weak_foot   skill_moves  \
# count      759.000000            759.000000  19239.000000  19239.000000
# mean     14480.848485             12.567852      2.946151      2.352461
# std      35328.730217              7.039116      0.671560      0.767659
# min       1318.000000              1.000000      1.000000      1.000000
# 25%       1338.000000              7.000000      3.000000      2.000000
# 50%       1357.000000             12.000000      3.000000      2.000000
# 75%       1386.000000             19.000000      3.000000      3.000000
# max     111473.000000             28.000000      5.000000      5.000000
#
#        international_reputation  release_clause_eur          pace  \
# count              19239.000000        1.806300e+04  17107.000000
# mean                   1.094184        5.374044e+06     68.213071
# std                    0.371098        1.494837e+07     10.933155
# min                    1.000000        1.600000e+04     28.000000
# 25%                    1.000000        8.060000e+05     62.000000
# 50%                    1.000000        1.600000e+06     69.000000
# 75%                    1.000000        3.700000e+06     76.000000
# max                    5.000000        3.735000e+08     97.000000
#
#            shooting       passing     dribbling     defending        physic  \
# count  17107.000000  17107.000000  17107.000000  17107.000000  17107.000000
# mean      52.345297     57.312562     62.561174     51.703630     64.823289
# std       14.051623     10.068965      9.651312     16.189746      9.791886
# min       18.000000     25.000000     27.000000     14.000000     29.000000
# 25%       42.000000     51.000000     57.000000     37.000000     59.000000
# 50%       54.000000     58.000000     64.000000     56.000000     66.000000
# 75%       63.000000     64.000000     69.000000     64.000000     72.000000
# max       94.000000     93.000000     95.000000     91.000000     90.000000
#
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# count        19239.000000         19239.000000                19239.000000
# mean            49.577421            45.894433                   51.783877
# std             18.034661            19.721023                   17.294183
# min              6.000000             2.000000                    5.000000
# 25%             38.000000            30.000000                   44.000000
# 50%             54.000000            50.000000                   55.000000
# 75%             63.000000            62.000000                   64.000000
# max             94.000000            95.000000                   93.000000
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# count             19239.000000       19239.000000     19239.000000
# mean                 58.867977          42.463849        55.660429
# std                  14.490858          17.653329        18.784590
# min                   7.000000           3.000000         4.000000
# 25%                  54.000000          30.000000        50.000000
# 50%                  62.000000          43.000000        61.000000
# 75%                  68.000000          56.000000        68.000000
# max                  94.000000          90.000000        96.000000
#
#         skill_curve  skill_fk_accuracy  skill_long_passing  \
# count  19239.000000       19239.000000        19239.000000
# mean      47.268933          42.249025           53.072249
# std       18.181085          17.178590           15.026569
# min        6.000000           4.000000            9.000000
# 25%       35.000000          31.000000           44.000000
# 50%       49.000000          41.000000           56.000000
# 75%       61.000000          55.000000           64.000000
# max       94.000000          94.000000           93.000000
#
#        skill_ball_control  movement_acceleration  movement_sprint_speed  \
# count        19239.000000           19239.000000           19239.000000
# mean            58.472010              64.652893              64.714902
# std             16.663722              15.167399              14.965426
# min              8.000000              14.000000              15.000000
# 25%             55.000000              57.000000              58.000000
# 50%             63.000000              67.000000              68.000000
# 75%             69.000000              75.000000              75.000000
# max             96.000000              97.000000              97.000000
#
#        movement_agility  movement_reactions  movement_balance  \
# count      19239.000000        19239.000000      19239.000000
# mean          63.500078           61.450023         64.068611
# std           14.862285            9.042281         14.324789
# min           18.000000           25.000000         15.000000
# 25%           55.000000           56.000000         56.000000
# 50%           66.000000           62.000000         66.000000
# 75%           74.000000           67.000000         74.000000
# max           96.000000           94.000000         96.000000
#
#        power_shot_power  power_jumping  power_stamina  power_strength  \
# count      19239.000000   19239.000000   19239.000000    19239.000000
# mean          57.776860      64.813504      63.084880       65.007745
# std           13.192224      12.122977      16.145279       12.663518
# min           20.000000      22.000000      12.000000       19.000000
# 25%           48.000000      57.000000      56.000000       57.000000
# 50%           59.000000      65.000000      66.000000       66.000000
# 75%           68.000000      73.000000      74.000000       74.000000
# max           95.000000      95.000000      97.000000       97.000000
#
#        power_long_shots  mentality_aggression  mentality_interceptions  \
# count      19239.000000          19239.000000             19239.000000
# mean          46.642705             55.538957                46.613545
# std           19.411583             16.972181                20.677077
# min            4.000000             10.000000                 3.000000
# 25%           32.000000             44.000000                26.000000
# 50%           51.000000             58.000000                53.000000
# 75%           62.000000             68.000000                64.000000
# max           94.000000             95.000000                91.000000
#
#        mentality_positioning  mentality_vision  mentality_penalties  \
# count           19239.000000      19239.000000         19239.000000
# mean               50.330215         53.964603            47.858724
# std                19.621601         13.650481            15.768583
# min                 2.000000         10.000000             7.000000
# 25%                40.000000         45.000000            38.000000
# 50%                56.000000         55.000000            49.000000
# 75%                64.000000         64.000000            60.000000
# max                96.000000         95.000000            93.000000
#
#        mentality_composure  defending_marking_awareness  \
# count         19239.000000                 19239.000000
# mean             57.929830                    46.601746
# std              12.159326                    20.200807
# min              12.000000                     4.000000
# 25%              50.000000                    29.000000
# 50%              59.000000                    52.000000
# 75%              66.000000                    63.000000
# max              96.000000                    93.000000
#
#        defending_standing_tackle  defending_sliding_tackle  \
# count               19239.000000              19239.000000
# mean                   48.045584                 45.906700
# std                    21.232718                 20.755683
# min                     5.000000                  5.000000
# 25%                    28.000000                 25.000000
# 50%                    56.000000                 53.000000
# 75%                    65.000000                 63.000000
# max                    93.000000                 92.000000
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# count        19239.000000          19239.000000         19239.000000
# mean            16.406102             16.192474            16.055356
# std             17.574028             16.839528            16.564554
# min              2.000000              2.000000             2.000000
# 25%              8.000000              8.000000             8.000000
# 50%             11.000000             11.000000            11.000000
# 75%             14.000000             14.000000            14.000000
# max             91.000000             92.000000            93.000000
#
#        goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed
# count             19239.000000          19239.000000        2132.000000
# mean                 16.229274             16.491814          36.439962
# std                  17.059779             17.884833          10.751563
# min                   2.000000              2.000000          15.000000
# 25%                   8.000000              8.000000          27.000000
# 50%                  11.000000             11.000000          36.000000
# 75%                  14.000000             14.000000          45.000000
# max                  92.000000             90.000000          65.000000

# %% [markdown]
# tipos de variables:

# %%
# da error 'DataFrame' object has no attribute 'Crossing' validar luego 

# print(df.Crossing.max()-df.Crossing.min()+1)
# nbins=89
# print(df['Crossing'].unique())
# df['Crossing'].hist(bins = nbins)

# %%
print(df.overall)
# Out:
# 0        93
# 1        92
# 2        91
# 3        91
# 4        91
#          ..
# 19234    47
# 19235    47
# 19236    47
# 19237    47
# 19238    47
# Name: overall, Length: 19239, dtype: int64

# %% [markdown]
# **Realizamos el histograma de la variable "Overall" (Desempeño global)**

# %%
nbins=1*(df.overall.max()-df.overall.min())+1
df['overall'].hist(bins = nbins)
print(nbins)
# Out:
# 47

# %% [markdown]
# La variable **'Overall'** se calcula usando otras variables de desempeño del jugador (skills_ratings), utilizando redondeo
#
# La variable 'Overall' es numérica discreta, (pero de "naturaleza" continua) así como las otras de desempeño según habilidad ('Crossing',
#        'Finishing', 'HeadingAccuracy', etc.), tomando valores enteros entre 0 y 100, más allá del tipo de dato en estos casos.
#
# Miramos ahora los mejores jugadores por posicion, usando las variables 'Overall' y 'Position'.

# %% [markdown]
# Mejores jugadores por posición:

# %%
df.head(3)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
#
#    overall  potential    value_eur  wage_eur  age         dob  height_cm  \
# 0       93         93   78000000.0  320000.0   34  1987-06-24        170
# 1       92         92  119500000.0  270000.0   32  1988-08-21        185
# 2       91         91   45000000.0  270000.0   36  1985-02-05        187
#
#    weight_kg  club_team_id            club_name             league_name  \
# 0         72          73.0  Paris Saint-Germain          French Ligue 1
# 1         81          21.0    FC Bayern München    German 1. Bundesliga
# 2         83          11.0    Manchester United  English Premier League
#
#    league_level club_position  club_jersey_number club_loaned_from  \
# 0           1.0            RW                30.0              NaN
# 1           1.0            ST                 9.0              NaN
# 2           1.0            ST                 7.0              NaN
#
#   club_joined  club_contract_valid_until  nationality_id nationality_name  \
# 0  2021-08-10                     2023.0              52        Argentina
# 1  2014-07-01                     2023.0              37           Poland
# 2  2021-08-27                     2023.0              38         Portugal
#
#    nation_team_id nation_position  nation_jersey_number preferred_foot  \
# 0          1369.0              RW                  10.0           Left
# 1          1353.0              RS                   9.0          Right
# 2          1354.0              ST                   7.0          Right
#
#    weak_foot  skill_moves  international_reputation    work_rate body_type  \
# 0          4            4                         5   Medium/Low    Unique
# 1          4            4                         5  High/Medium    Unique
# 2          4            5                         5     High/Low    Unique
#
#   real_face  release_clause_eur  \
# 0       Yes         144300000.0
# 1       Yes         197200000.0
# 2       Yes          83300000.0
#
#                                          player_tags  \
# 0  #Dribbler, #Distance Shooter, #FK Specialist, ...
# 1  #Aerial Threat, #Distance Shooter, #Clinical F...
# 2  #Aerial Threat, #Dribbler, #Distance Shooter, ...
#
#                                        player_traits  pace  shooting  passing  \
# 0  Finesse Shot, Long Shot Taker (AI), Playmaker ...  85.0      92.0     91.0
# 1  Solid Player, Finesse Shot, Outside Foot Shot,...  78.0      92.0     79.0
# 2  Power Free-Kick, Flair, Long Shot Taker (AI), ...  87.0      94.0     80.0
#
#    dribbling  defending  physic  attacking_crossing  attacking_finishing  \
# 0       95.0       34.0    65.0                  85                   95
# 1       86.0       44.0    82.0                  71                   95
# 2       88.0       34.0    75.0                  87                   95
#
#    attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                          70                       91                 88
# 1                          90                       85                 89
# 2                          90                       80                 86
#
#    skill_dribbling  skill_curve  ...  power_stamina  power_strength  \
# 0               96           93  ...             72              69
# 1               85           79  ...             76              86
# 2               88           81  ...             77              77
#
#    power_long_shots  mentality_aggression  mentality_interceptions  \
# 0                94                    44                       40
# 1                87                    81                       49
# 2                93                    63                       29
#
#    mentality_positioning  mentality_vision  mentality_penalties  \
# 0                     93                95                   75
# 1                     95                81                   90
# 2                     95                76                   88
#
#    mentality_composure  defending_marking_awareness  \
# 0                   96                           20
# 1                   88                           35
# 2                   95                           24
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         35                        24                   6
# 1                         42                        19                  15
# 2                         32                        24                   7
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                     6                   12                        8
# 2                    11                   15                       14
#
#    goalkeeping_reflexes  goalkeeping_speed    ls    st    rs  lw  lf  cf  rf  \
# 0                     8                NaN  89+3  89+3  89+3  92  93  93  93
# 1                    10                NaN  90+2  90+2  90+2  85  88  88  88
# 2                    11                NaN  90+1  90+1  90+1  88  89  89  89
#
#    rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm  \
# 0  92    93    93    93  91+2  87+3  87+3  87+3  91+2  66+3  64+3  64+3  64+3
# 1  85  86+3  86+3  86+3  84+3  80+3  80+3  80+3  84+3  64+3  66+3  66+3  66+3
# 2  88  86+3  86+3  86+3  86+3  78+3  78+3  78+3  86+3  63+3  59+3  59+3  59+3
#
#     rwb    lb   lcb    cb   rcb    rb    gk  \
# 0  66+3  61+3  50+3  50+3  50+3  61+3  19+3
# 1  64+3  61+3  60+3  60+3  60+3  61+3  19+3
# 2  63+3  60+3  53+3  53+3  53+3  60+3  20+3
#
#                                      player_face_url  \
# 0  https://cdn.sofifa.net/players/158/023/22_120.png
# 1  https://cdn.sofifa.net/players/188/545/22_120.png
# 2  https://cdn.sofifa.net/players/020/801/22_120.png
#
#                             club_logo_url  \
# 0  https://cdn.sofifa.net/teams/73/60.png
# 1  https://cdn.sofifa.net/teams/21/60.png
# 2  https://cdn.sofifa.net/teams/11/60.png
#
#                              club_flag_url  \
# 0      https://cdn.sofifa.net/flags/fr.png
# 1      https://cdn.sofifa.net/flags/de.png
# 2  https://cdn.sofifa.net/flags/gb-eng.png
#
#                             nation_logo_url  \
# 0  https://cdn.sofifa.net/teams/1369/60.png
# 1  https://cdn.sofifa.net/teams/1353/60.png
# 2  https://cdn.sofifa.net/teams/1354/60.png
#
#                        nation_flag_url
# 0  https://cdn.sofifa.net/flags/ar.png
# 1  https://cdn.sofifa.net/flags/pl.png
# 2  https://cdn.sofifa.net/flags/pt.png
#
# [3 rows x 110 columns]

# %%
best_players_per_position=df.iloc[df.groupby(df['club_position'])['overall'].idxmax()][['club_position','long_name','overall']]
best_players_per_position.sort_values(by=['overall'], ascending=False)
# Out:
#     club_position                          long_name  overall
# 0              RW     Lionel Andrés Messi Cuccittini       93
# 1              ST                 Robert Lewandowski       92
# 3              LW      Neymar da Silva Santos Júnior       91
# 4             RCM                    Kevin De Bruyne       91
# 5              GK                          Jan Oblak       91
# 14            CDM  Carlos Henrique Venancio Casimiro       89
# 11             CF                      Karim Benzema       89
# 15            LCB                    Virgil van Dijk       89
# 19            RDM              Joshua Walter Kimmich       89
# 23             RS           Luis Alberto Suárez Díaz       88
# 28            CAM      Bruno Miguel Borges Fernandes       88
# 24            LCM                         Toni Kroos       88
# 26            SUB                Keylor Navas Gamboa       88
# 44             RB             Trent Alexander-Arnold       87
# 39            RCB                 Marcos Aoás Corrêa       87
# 40            LDM            Leon Christoph Goretzka       87
# 45             LM                       Jadon Sancho       87
# 42             LB                   Andrew Robertson       87
# 66             RM             Marcos Llorente Moreno       86
# 83             LS                  Antoine Griezmann       85
# 84             CB                     Stefan de Vrij       85
# 146           RES                     Jérôme Boateng       83
# 162            RF                      Kevin Volland       83
# 148           RWB            César Azpilicueta Tanco       83
# 239           LWB          Alejandro Grimaldo García       82
# 219            CM                 Idrissa Gana Gueye       82
# 373           LAM                 Christopher Nkunku       81
# 415            LF    Marcelo Nicolás Lodeiro Benítez       80
# 813           RAM              G. Pierre Paiva Souza       78

# %% [markdown]
# Conteos por posiciones

# %%
pd.DataFrame(df.club_position.value_counts()).sort_values(by=['club_position'], ascending=False)
# Out:
#      club_position
# SUB           8299
# RES           3168
# RCB            701
# GK             701
# LCB            701
# RB             515
# LB             515
# ST             476
# RCM            470
# LCM            470
# LM             410
# RM             410
# CAM            292
# LS             223
# RS             223
# RDM            223
# LDM            223
# CB             186
# RW             185
# LW             185
# CDM            168
# RWB            116
# LWB            116
# CM              83
# RF              35
# LF              35
# LAM             21
# RAM             21
# CF               7

# %% [markdown]
# Mejores Promedios de Overall por equipos

# %%
# club_avg_overall=df.groupby("Club")["Overall"].mean().reset_index().sort_values("Overall",ascending=False)
# club_avg_overall.head(8)

# %%
def status(data):

    data2=data 

    # total de rows
    tot_rows=len(data2)
    
    # total de nan
    d2=data2.isnull().sum().reset_index()
    d2.columns=['variable', 'q_nan']
    
    # percentage of nan
    d2[['p_nan']]=d2[['q_nan']]/tot_rows
    
    # num of zeros
    d2['q_zeros']=(data2==0).sum().values

    # perc of zeros
    d2['p_zeros']=d2[['q_zeros']]/tot_rows

    # total unique values
    d2['unique']=data2.nunique().values
    
    # get data types per column
    d2['type']=[str(x) for x in data2.dtypes.values]
    
    return(d2)

# %%
status(df)
# Out:
#                         variable  q_nan     p_nan  q_zeros  p_zeros  unique  \
# 0                      sofifa_id      0  0.000000        0      0.0   19239
# 1                     player_url      0  0.000000        0      0.0   19239
# 2                     short_name      0  0.000000        0      0.0   18145
# 3                      long_name      0  0.000000        0      0.0   19219
# 4               player_positions      0  0.000000        0      0.0     674
# 5                        overall      0  0.000000        0      0.0      47
# 6                      potential      0  0.000000        0      0.0      46
# 7                      value_eur     74  0.003846        0      0.0     252
# 8                       wage_eur     61  0.003171        0      0.0     133
# 9                            age      0  0.000000        0      0.0      29
# 10                           dob      0  0.000000        0      0.0    6312
# 11                     height_cm      0  0.000000        0      0.0      49
# 12                     weight_kg      0  0.000000        0      0.0      58
# 13                  club_team_id     61  0.003171        0      0.0     701
# 14                     club_name     61  0.003171        0      0.0     701
# 15                   league_name     61  0.003171        0      0.0      55
# 16                  league_level     61  0.003171        0      0.0       5
# 17                 club_position     61  0.003171        0      0.0      29
# 18            club_jersey_number     61  0.003171        0      0.0      99
# 19              club_loaned_from  18137  0.942721        0      0.0     334
# 20                   club_joined   1163  0.060450        0      0.0    1845
# 21     club_contract_valid_until     61  0.003171        0      0.0       9
# 22                nationality_id      0  0.000000        0      0.0     163
# 23              nationality_name      0  0.000000        0      0.0     163
# 24                nation_team_id  18480  0.960549        0      0.0      33
# 25               nation_position  18480  0.960549        0      0.0      28
# 26          nation_jersey_number  18480  0.960549        0      0.0      28
# 27                preferred_foot      0  0.000000        0      0.0       2
# 28                     weak_foot      0  0.000000        0      0.0       5
# 29                   skill_moves      0  0.000000        0      0.0       5
# 30      international_reputation      0  0.000000        0      0.0       5
# 31                     work_rate      0  0.000000        0      0.0       9
# 32                     body_type      0  0.000000        0      0.0      10
# 33                     real_face      0  0.000000        0      0.0       2
# 34            release_clause_eur   1176  0.061126        0      0.0    1235
# 35                   player_tags  17798  0.925100        0      0.0      71
# 36                 player_traits   9841  0.511513        0      0.0    1051
# 37                          pace   2132  0.110817        0      0.0      70
# 38                      shooting   2132  0.110817        0      0.0      76
# 39                       passing   2132  0.110817        0      0.0      67
# 40                     dribbling   2132  0.110817        0      0.0      68
# 41                     defending   2132  0.110817        0      0.0      77
# 42                        physic   2132  0.110817        0      0.0      61
# 43            attacking_crossing      0  0.000000        0      0.0      88
# 44           attacking_finishing      0  0.000000        0      0.0      94
# 45    attacking_heading_accuracy      0  0.000000        0      0.0      89
# 46       attacking_short_passing      0  0.000000        0      0.0      86
# 47             attacking_volleys      0  0.000000        0      0.0      88
# 48               skill_dribbling      0  0.000000        0      0.0      92
# 49                   skill_curve      0  0.000000        0      0.0      89
# 50             skill_fk_accuracy      0  0.000000        0      0.0      90
# 51            skill_long_passing      0  0.000000        0      0.0      85
# 52            skill_ball_control      0  0.000000        0      0.0      88
# 53         movement_acceleration      0  0.000000        0      0.0      84
# 54         movement_sprint_speed      0  0.000000        0      0.0      83
# 55              movement_agility      0  0.000000        0      0.0      79
# 56            movement_reactions      0  0.000000        0      0.0      67
# 57              movement_balance      0  0.000000        0      0.0      79
# 58              power_shot_power      0  0.000000        0      0.0      76
# 59                 power_jumping      0  0.000000        0      0.0      71
# 60                 power_stamina      0  0.000000        0      0.0      86
# 61                power_strength      0  0.000000        0      0.0      77
# 62              power_long_shots      0  0.000000        0      0.0      90
# 63          mentality_aggression      0  0.000000        0      0.0      86
# 64       mentality_interceptions      0  0.000000        0      0.0      89
# 65         mentality_positioning      0  0.000000        0      0.0      95
# 66              mentality_vision      0  0.000000        0      0.0      85
# 67           mentality_penalties      0  0.000000        0      0.0      87
# 68           mentality_composure      0  0.000000        0      0.0      85
# 69   defending_marking_awareness      0  0.000000        0      0.0      89
# 70     defending_standing_tackle      0  0.000000        0      0.0      88
# 71      defending_sliding_tackle      0  0.000000        0      0.0      88
# 72            goalkeeping_diving      0  0.000000        0      0.0      71
# 73          goalkeeping_handling      0  0.000000        0      0.0      69
# 74           goalkeeping_kicking      0  0.000000        0      0.0      79
# 75       goalkeeping_positioning      0  0.000000        0      0.0      77
# 76          goalkeeping_reflexes      0  0.000000        0      0.0      70
# 77             goalkeeping_speed  17107  0.889183        0      0.0      51
# 78                            ls      0  0.000000        0      0.0     228
# 79                            st      0  0.000000        0      0.0     228
# 80                            rs      0  0.000000        0      0.0     228
# 81                            lw      0  0.000000        0      0.0     138
# 82                            lf      0  0.000000        0      0.0     132
# 83                            cf      0  0.000000        0      0.0     132
# 84                            rf      0  0.000000        0      0.0     132
# 85                            rw      0  0.000000        0      0.0     138
# 86                           lam      0  0.000000        0      0.0     252
# 87                           cam      0  0.000000        0      0.0     252
# 88                           ram      0  0.000000        0      0.0     252
# 89                            lm      0  0.000000        0      0.0     235
# 90                           lcm      0  0.000000        0      0.0     212
# 91                            cm      0  0.000000        0      0.0     212
# 92                           rcm      0  0.000000        0      0.0     212
# 93                            rm      0  0.000000        0      0.0     235
# 94                           lwb      0  0.000000        0      0.0     196
# 95                           ldm      0  0.000000        0      0.0     239
# 96                           cdm      0  0.000000        0      0.0     239
# 97                           rdm      0  0.000000        0      0.0     239
# 98                           rwb      0  0.000000        0      0.0     196
# 99                            lb      0  0.000000        0      0.0     193
# 100                          lcb      0  0.000000        0      0.0     259
# 101                           cb      0  0.000000        0      0.0     259
# 102                          rcb      0  0.000000        0      0.0     259
# 103                           rb      0  0.000000        0      0.0     193
# 104                           gk      0  0.000000        0      0.0     115
# 105              player_face_url      0  0.000000        0      0.0   19239
# 106                club_logo_url     61  0.003171        0      0.0     701
# 107                club_flag_url     61  0.003171        0      0.0      49
# 108              nation_logo_url  18480  0.960549        0      0.0      33
# 109              nation_flag_url      0  0.000000        0      0.0     163
#
#         type
# 0      int64
# 1     object
# 2     object
# 3     object
# 4     object
# 5      int64
# 6      int64
# 7    float64
# 8    float64
# 9      int64
# 10    object
# 11     int64
# 12     int64
# 13   float64
# 14    object
# 15    object
# 16   float64
# 17    object
# 18   float64
# 19    object
# 20    object
# 21   float64
# 22     int64
# 23    object
# 24   float64
# 25    object
# 26   float64
# 27    object
# 28     int64
# 29     int64
# 30     int64
# 31    object
# 32    object
# 33    object
# 34   float64
# 35    object
# 36    object
# 37   float64
# 38   float64
# 39   float64
# 40   float64
# 41   float64
# 42   float64
# 43     int64
# 44     int64
# 45     int64
# 46     int64
# 47     int64
# 48     int64
# 49     int64
# 50     int64
# 51     int64
# 52     int64
# 53     int64
# 54     int64
# 55     int64
# 56     int64
# 57     int64
# 58     int64
# 59     int64
# 60     int64
# 61     int64
# 62     int64
# 63     int64
# 64     int64
# 65     int64
# 66     int64
# 67     int64
# 68     int64
# 69     int64
# 70     int64
# 71     int64
# 72     int64
# 73     int64
# 74     int64
# 75     int64
# 76     int64
# 77   float64
# 78    object
# 79    object
# 80    object
# 81    object
# 82    object
# 83    object
# 84    object
# 85    object
# 86    object
# 87    object
# 88    object
# 89    object
# 90    object
# 91    object
# 92    object
# 93    object
# 94    object
# 95    object
# 96    object
# 97    object
# 98    object
# 99    object
# 100   object
# 101   object
# 102   object
# 103   object
# 104   object
# 105   object
# 106   object
# 107   object
# 108   object
# 109   object

# %% [markdown]
# ## 2.-Preparación-de-los-datos-a analizar

# %% [markdown]
# **Reducimos el tamaño de la base. Retiramos jugadores con bajo Desempeño global ("Overall"),**
#
# **y consideramos Variables de desempeño por habilidad (skills_ratings)**

# %%
df_filter_overall = df[(df['overall']>70)]
df_filter_overall.head(3)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
#
#    overall  potential    value_eur  wage_eur  age         dob  height_cm  \
# 0       93         93   78000000.0  320000.0   34  1987-06-24        170
# 1       92         92  119500000.0  270000.0   32  1988-08-21        185
# 2       91         91   45000000.0  270000.0   36  1985-02-05        187
#
#    weight_kg  club_team_id            club_name             league_name  \
# 0         72          73.0  Paris Saint-Germain          French Ligue 1
# 1         81          21.0    FC Bayern München    German 1. Bundesliga
# 2         83          11.0    Manchester United  English Premier League
#
#    league_level club_position  club_jersey_number club_loaned_from  \
# 0           1.0            RW                30.0              NaN
# 1           1.0            ST                 9.0              NaN
# 2           1.0            ST                 7.0              NaN
#
#   club_joined  club_contract_valid_until  nationality_id nationality_name  \
# 0  2021-08-10                     2023.0              52        Argentina
# 1  2014-07-01                     2023.0              37           Poland
# 2  2021-08-27                     2023.0              38         Portugal
#
#    nation_team_id nation_position  nation_jersey_number preferred_foot  \
# 0          1369.0              RW                  10.0           Left
# 1          1353.0              RS                   9.0          Right
# 2          1354.0              ST                   7.0          Right
#
#    weak_foot  skill_moves  international_reputation    work_rate body_type  \
# 0          4            4                         5   Medium/Low    Unique
# 1          4            4                         5  High/Medium    Unique
# 2          4            5                         5     High/Low    Unique
#
#   real_face  release_clause_eur  \
# 0       Yes         144300000.0
# 1       Yes         197200000.0
# 2       Yes          83300000.0
#
#                                          player_tags  \
# 0  #Dribbler, #Distance Shooter, #FK Specialist, ...
# 1  #Aerial Threat, #Distance Shooter, #Clinical F...
# 2  #Aerial Threat, #Dribbler, #Distance Shooter, ...
#
#                                        player_traits  pace  shooting  passing  \
# 0  Finesse Shot, Long Shot Taker (AI), Playmaker ...  85.0      92.0     91.0
# 1  Solid Player, Finesse Shot, Outside Foot Shot,...  78.0      92.0     79.0
# 2  Power Free-Kick, Flair, Long Shot Taker (AI), ...  87.0      94.0     80.0
#
#    dribbling  defending  physic  attacking_crossing  attacking_finishing  \
# 0       95.0       34.0    65.0                  85                   95
# 1       86.0       44.0    82.0                  71                   95
# 2       88.0       34.0    75.0                  87                   95
#
#    attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                          70                       91                 88
# 1                          90                       85                 89
# 2                          90                       80                 86
#
#    skill_dribbling  skill_curve  ...  power_stamina  power_strength  \
# 0               96           93  ...             72              69
# 1               85           79  ...             76              86
# 2               88           81  ...             77              77
#
#    power_long_shots  mentality_aggression  mentality_interceptions  \
# 0                94                    44                       40
# 1                87                    81                       49
# 2                93                    63                       29
#
#    mentality_positioning  mentality_vision  mentality_penalties  \
# 0                     93                95                   75
# 1                     95                81                   90
# 2                     95                76                   88
#
#    mentality_composure  defending_marking_awareness  \
# 0                   96                           20
# 1                   88                           35
# 2                   95                           24
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         35                        24                   6
# 1                         42                        19                  15
# 2                         32                        24                   7
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                     6                   12                        8
# 2                    11                   15                       14
#
#    goalkeeping_reflexes  goalkeeping_speed    ls    st    rs  lw  lf  cf  rf  \
# 0                     8                NaN  89+3  89+3  89+3  92  93  93  93
# 1                    10                NaN  90+2  90+2  90+2  85  88  88  88
# 2                    11                NaN  90+1  90+1  90+1  88  89  89  89
#
#    rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm  \
# 0  92    93    93    93  91+2  87+3  87+3  87+3  91+2  66+3  64+3  64+3  64+3
# 1  85  86+3  86+3  86+3  84+3  80+3  80+3  80+3  84+3  64+3  66+3  66+3  66+3
# 2  88  86+3  86+3  86+3  86+3  78+3  78+3  78+3  86+3  63+3  59+3  59+3  59+3
#
#     rwb    lb   lcb    cb   rcb    rb    gk  \
# 0  66+3  61+3  50+3  50+3  50+3  61+3  19+3
# 1  64+3  61+3  60+3  60+3  60+3  61+3  19+3
# 2  63+3  60+3  53+3  53+3  53+3  60+3  20+3
#
#                                      player_face_url  \
# 0  https://cdn.sofifa.net/players/158/023/22_120.png
# 1  https://cdn.sofifa.net/players/188/545/22_120.png
# 2  https://cdn.sofifa.net/players/020/801/22_120.png
#
#                             club_logo_url  \
# 0  https://cdn.sofifa.net/teams/73/60.png
# 1  https://cdn.sofifa.net/teams/21/60.png
# 2  https://cdn.sofifa.net/teams/11/60.png
#
#                              club_flag_url  \
# 0      https://cdn.sofifa.net/flags/fr.png
# 1      https://cdn.sofifa.net/flags/de.png
# 2  https://cdn.sofifa.net/flags/gb-eng.png
#
#                             nation_logo_url  \
# 0  https://cdn.sofifa.net/teams/1369/60.png
# 1  https://cdn.sofifa.net/teams/1353/60.png
# 2  https://cdn.sofifa.net/teams/1354/60.png
#
#                        nation_flag_url
# 0  https://cdn.sofifa.net/flags/ar.png
# 1  https://cdn.sofifa.net/flags/pl.png
# 2  https://cdn.sofifa.net/flags/pt.png
#
# [3 rows x 110 columns]

# %% [markdown]
# ### Tomamos solo los skills, las diferentes posiciones y el id para validar mas adelante valores faltantes

# %%
skills_ratings = ['sofifa_id','club_position','pace','shooting','passing','dribbling','defending','physic','attacking_crossing','attacking_finishing',
'attacking_heading_accuracy','attacking_short_passing','attacking_volleys','skill_dribbling','skill_curve','skill_fk_accuracy','skill_long_passing',
'skill_ball_control','movement_acceleration','movement_sprint_speed','movement_agility','movement_reactions','movement_balance','power_shot_power',
'power_jumping','power_stamina','power_strength','power_long_shots','mentality_aggression','mentality_interceptions','mentality_positioning','mentality_vision',
'mentality_penalties','mentality_composure','defending_marking_awareness','defending_standing_tackle','defending_sliding_tackle','goalkeeping_diving',
'goalkeeping_handling','goalkeeping_kicking','goalkeeping_positioning','goalkeeping_reflexes','goalkeeping_speed']

print(len(skills_ratings), 'variables numéricas de desempeño según habilidad')

df_skills = df_filter_overall[skills_ratings]

df_skills.rename(columns={'club_position': 'position'}, inplace=True)
# df_skills = df_skills.columns.str.replace('club_position', 'position')
# Out:
# 43 variables numéricas de desempeño según habilidad

# %%
df_skills
# Out:
#       sofifa_id position  pace  shooting  passing  dribbling  defending  \
# 0        158023       RW  85.0      92.0     91.0       95.0       34.0
# 1        188545       ST  78.0      92.0     79.0       86.0       44.0
# 2         20801       ST  87.0      94.0     80.0       88.0       34.0
# 3        190871       LW  91.0      83.0     86.0       94.0       37.0
# 4        192985      RCM  76.0      86.0     93.0       88.0       64.0
# ...         ...      ...   ...       ...      ...        ...        ...
# 4588     261987      RES  61.0      56.0     67.0       66.0       62.0
# 4589     262411      SUB  67.0      64.0     70.0       72.0       68.0
# 4590     262815       RB  81.0      51.0     66.0       70.0       66.0
# 4591     263230      SUB  76.0      70.0     60.0       65.0       39.0
# 4592     263383      SUB  61.0      62.0     67.0       71.0       65.0
#
#       physic  attacking_crossing  attacking_finishing  \
# 0       65.0                  85                   95
# 1       82.0                  71                   95
# 2       75.0                  87                   95
# 3       63.0                  85                   83
# 4       78.0                  94                   82
# ...      ...                 ...                  ...
# 4588    58.0                  46                   55
# 4589    79.0                  66                   60
# 4590    67.0                  70                   61
# 4591    71.0                  64                   74
# 4592    73.0                  57                   61
#
#       attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                             70                       91                 88
# 1                             90                       85                 89
# 2                             90                       80                 86
# 3                             63                       86                 86
# 4                             55                       94                 82
# ...                          ...                      ...                ...
# 4588                          49                       75                 37
# 4589                          62                       73                 58
# 4590                          49                       71                 29
# 4591                          72                       63                 58
# 4592                          54                       70                 61
#
#       skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  \
# 0                  96           93                 94                  91
# 1                  85           79                 85                  70
# 2                  88           81                 84                  77
# 3                  95           88                 87                  81
# 4                  88           85                 83                  93
# ...               ...          ...                ...                 ...
# 4588               65           56                 65                  73
# 4589               73           73                 63                  70
# 4590               71           74                 35                  69
# 4591               66           56                 49                  57
# 4592               71           60                 49                  74
#
#       skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 0                     96                     91                     80
# 1                     88                     77                     79
# 2                     88                     85                     88
# 3                     95                     93                     89
# 4                     91                     76                     76
# ...                  ...                    ...                    ...
# 4588                  70                     63                     59
# 4589                  70                     69                     66
# 4590                  72                     80                     82
# 4591                  65                     79                     74
# 4592                  78                     59                     62
#
#       movement_agility  movement_reactions  movement_balance  \
# 0                   91                  94                95
# 1                   77                  93                82
# 2                   86                  94                74
# 3                   96                  89                84
# 4                   79                  91                78
# ...                ...                 ...               ...
# 4588                61                  68                57
# 4589                74                  69                65
# 4590                67                  58                65
# 4591                55                  70                75
# 4592                53                  71                55
#
#       power_shot_power  power_jumping  power_stamina  power_strength  \
# 0                   86             68             72              69
# 1                   90             85             76              86
# 2                   94             95             77              77
# 3                   80             64             81              53
# 4                   91             63             89              74
# ...                ...            ...            ...             ...
# 4588                52             61             69              53
# 4589                73             67             81              77
# 4590                45             69             73              70
# 4591                74             68             65              74
# 4592                62             61             78              72
#
#       power_long_shots  mentality_aggression  mentality_interceptions  \
# 0                   94                    44                       40
# 1                   87                    81                       49
# 2                   93                    63                       29
# 3                   81                    63                       37
# 4                   91                    76                       66
# ...                ...                   ...                      ...
# 4588                64                    58                       69
# 4589                65                    83                       70
# 4590                40                    50                       64
# 4591                63                    70                       30
# 4592                66                    72                       66
#
#       mentality_positioning  mentality_vision  mentality_penalties  \
# 0                        93                95                   75
# 1                        95                81                   90
# 2                        95                76                   88
# 3                        86                90                   93
# 4                        88                94                   83
# ...                     ...               ...                  ...
# 4588                     67                75                   60
# 4589                     68                70                   66
# 4590                     65                59                   40
# 4591                     73                59                   63
# 4592                     68                71                   48
#
#       mentality_composure  defending_marking_awareness  \
# 0                      96                           20
# 1                      88                           35
# 2                      95                           24
# 3                      93                           35
# 4                      89                           68
# ...                   ...                          ...
# 4588                   73                           60
# 4589                   74                           61
# 4590                   70                           68
# 4591                   59                           35
# 4592                   74                           64
#
#       defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                            35                        24                   6
# 1                            42                        19                  15
# 2                            32                        24                   7
# 3                            32                        29                   9
# 4                            65                        53                  15
# ...                         ...                       ...                 ...
# 4588                         70                        46                  11
# 4589                         74                        69                  11
# 4590                         70                        67                  12
# 4591                         38                        34                  14
# 4592                         70                        61                  13
#
#       goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                       11                   15                       14
# 1                        6                   12                        8
# 2                       11                   15                       14
# 3                        9                   15                       15
# 4                       13                    5                       10
# ...                    ...                  ...                      ...
# 4588                     7                   13                       12
# 4589                     8                    8                       15
# 4590                    12                   11                       15
# 4591                    15                   14                       12
# 4592                    10                   10                        6
#
#       goalkeeping_reflexes  goalkeeping_speed
# 0                        8                NaN
# 1                       10                NaN
# 2                       11                NaN
# 3                       11                NaN
# 4                       13                NaN
# ...                    ...                ...
# 4588                     9                NaN
# 4589                     8                NaN
# 4590                     9                NaN
# 4591                     8                NaN
# 4592                     9                NaN
#
# [4593 rows x 43 columns]

# %% [markdown]
# ### Verificamos los valores nulos por cada columna para verificar como solucionar estos valores nulos

# %%
status(df_skills)
# Out:
#                        variable  q_nan     p_nan  q_zeros  p_zeros  unique  \
# 0                     sofifa_id      0  0.000000        0      0.0    4593
# 1                      position     25  0.005443        0      0.0      29
# 2                          pace    444  0.096669        0      0.0      69
# 3                      shooting    444  0.096669        0      0.0      74
# 4                       passing    444  0.096669        0      0.0      56
# 5                     dribbling    444  0.096669        0      0.0      56
# 6                     defending    444  0.096669        0      0.0      73
# 7                        physic    444  0.096669        0      0.0      54
# 8            attacking_crossing      0  0.000000        0      0.0      88
# 9           attacking_finishing      0  0.000000        0      0.0      93
# 10   attacking_heading_accuracy      0  0.000000        0      0.0      87
# 11      attacking_short_passing      0  0.000000        0      0.0      84
# 12            attacking_volleys      0  0.000000        0      0.0      87
# 13              skill_dribbling      0  0.000000        0      0.0      89
# 14                  skill_curve      0  0.000000        0      0.0      89
# 15            skill_fk_accuracy      0  0.000000        0      0.0      88
# 16           skill_long_passing      0  0.000000        0      0.0      84
# 17           skill_ball_control      0  0.000000        0      0.0      85
# 18        movement_acceleration      0  0.000000        0      0.0      79
# 19        movement_sprint_speed      0  0.000000        0      0.0      80
# 20             movement_agility      0  0.000000        0      0.0      77
# 21           movement_reactions      0  0.000000        0      0.0      45
# 22             movement_balance      0  0.000000        0      0.0      77
# 23             power_shot_power      0  0.000000        0      0.0      74
# 24                power_jumping      0  0.000000        0      0.0      67
# 25                power_stamina      0  0.000000        0      0.0      83
# 26               power_strength      0  0.000000        0      0.0      68
# 27             power_long_shots      0  0.000000        0      0.0      90
# 28         mentality_aggression      0  0.000000        0      0.0      85
# 29      mentality_interceptions      0  0.000000        0      0.0      86
# 30        mentality_positioning      0  0.000000        0      0.0      94
# 31             mentality_vision      0  0.000000        0      0.0      84
# 32          mentality_penalties      0  0.000000        0      0.0      86
# 33          mentality_composure      0  0.000000        0      0.0      76
# 34  defending_marking_awareness      0  0.000000        0      0.0      88
# 35    defending_standing_tackle      0  0.000000        0      0.0      86
# 36     defending_sliding_tackle      0  0.000000        0      0.0      86
# 37           goalkeeping_diving      0  0.000000        0      0.0      46
# 38         goalkeeping_handling      0  0.000000        0      0.0      47
# 39          goalkeeping_kicking      0  0.000000        0      0.0      58
# 40      goalkeeping_positioning      0  0.000000        0      0.0      49
# 41         goalkeeping_reflexes      0  0.000000        0      0.0      46
# 42            goalkeeping_speed   4149  0.903331        0      0.0      49
#
#        type
# 0     int64
# 1    object
# 2   float64
# 3   float64
# 4   float64
# 5   float64
# 6   float64
# 7   float64
# 8     int64
# 9     int64
# 10    int64
# 11    int64
# 12    int64
# 13    int64
# 14    int64
# 15    int64
# 16    int64
# 17    int64
# 18    int64
# 19    int64
# 20    int64
# 21    int64
# 22    int64
# 23    int64
# 24    int64
# 25    int64
# 26    int64
# 27    int64
# 28    int64
# 29    int64
# 30    int64
# 31    int64
# 32    int64
# 33    int64
# 34    int64
# 35    int64
# 36    int64
# 37    int64
# 38    int64
# 39    int64
# 40    int64
# 41    int64
# 42  float64

# %% [markdown]
# ### Verificaremos y resolveremos primero la columna de posiciones, para ello tomaremos la posicion del equipo nacional de estar en nulo.

# %%
df_skills_position = df_skills[['sofifa_id','position']

# %%
df_position_cruce = df_skills_position[df_skills_position.position.isnull()]
df_position_cruce
# Out:
#       sofifa_id position
# 147      184087      NaN
# 416      197242      NaN
# 694      187607      NaN
# 926      200094      NaN
# 1146     154950      NaN
# 1152     167575      NaN
# 1182     189060      NaN
# 1241     205211      NaN
# 1255     207554      NaN
# 1759     223058      NaN
# 2170     219409      NaN
# 2391     244700      NaN
# 2499     187533      NaN
# 2590     201884      NaN
# 2601     204121      NaN
# 2854     229585      NaN
# 2903     231493      NaN
# 3169     188537      NaN
# 3260     199904      NaN
# 3358     211592      NaN
# 3721     240225      NaN
# 3824     261529      NaN
# 3890     184477      NaN
# 4390     235973      NaN
# 4442     240309      NaN

# %%
df_position_cruce_gen = df[df['sofifa_id'].isin(df_position_cruce['sofifa_id'])]
df_position_cruce_gen.head()
# Out:
#       sofifa_id                                         player_url  \
# 147      184087  https://sofifa.com/player/184087/toby-alderwei...
# 416      197242  https://sofifa.com/player/197242/grzegorz-kryc...
# 694      187607  https://sofifa.com/player/187607/artem-dzyuba/...
# 926      200094  https://sofifa.com/player/200094/magomed-ozdoe...
# 1146     154950  https://sofifa.com/player/154950/yuriy-zhirkov...
#
#            short_name            long_name player_positions  overall  \
# 147   T. Alderweireld    Toby Alderweireld               CB       83
# 416     G. Krychowiak  Grzegorz Krychowiak          CDM, CM       80
# 694         A. Dzyuba         Artem Dzyuba               ST       78
# 926         M. Ozdoev       Magomed Ozdoev          CDM, CM       77
# 1146       Y. Zhirkov        Yuriy Zhirkov           LB, LM       76
#
#       potential  value_eur  wage_eur  age         dob  height_cm  weight_kg  \
# 147          83        NaN       NaN   32  1989-03-02        186         81
# 416          80        NaN       NaN   31  1990-01-29        187         84
# 694          78        NaN       NaN   32  1988-08-22        196         91
# 926          78        NaN       NaN   28  1992-11-05        184         78
# 1146         76        NaN       NaN   37  1983-08-20        180         75
#
#       club_team_id club_name league_name  league_level club_position  \
# 147            NaN       NaN         NaN           NaN           NaN
# 416            NaN       NaN         NaN           NaN           NaN
# 694            NaN       NaN         NaN           NaN           NaN
# 926            NaN       NaN         NaN           NaN           NaN
# 1146           NaN       NaN         NaN           NaN           NaN
#
#       club_jersey_number club_loaned_from club_joined  \
# 147                  NaN              NaN         NaN
# 416                  NaN              NaN         NaN
# 694                  NaN              NaN         NaN
# 926                  NaN              NaN         NaN
# 1146                 NaN              NaN         NaN
#
#       club_contract_valid_until  nationality_id nationality_name  \
# 147                         NaN               7          Belgium
# 416                         NaN              37           Poland
# 694                         NaN              40           Russia
# 926                         NaN              40           Russia
# 1146                        NaN              40           Russia
#
#       nation_team_id nation_position  nation_jersey_number preferred_foot  \
# 147           1325.0             RCB                   2.0          Right
# 416           1353.0             CDM                  10.0          Right
# 694           1357.0              ST                  22.0          Right
# 926           1357.0             RDM                   7.0          Right
# 1146          1357.0              LM                  18.0           Left
#
#       weak_foot  skill_moves  international_reputation      work_rate  \
# 147           3            2                         3  Medium/Medium
# 416           3            3                         3      High/High
# 694           3            3                         2     Medium/Low
# 926           3            3                         1    Medium/High
# 1146          2            4                         2    High/Medium
#
#              body_type real_face  release_clause_eur  \
# 147      Normal (185+)       Yes                 NaN
# 416      Normal (185+)        No                 NaN
# 694      Normal (185+)        No                 NaN
# 926   Normal (170-185)        No                 NaN
# 1146    Lean (170-185)       Yes                 NaN
#
#                     player_tags                           player_traits  pace  \
# 147                         NaN                        Long Passer (AI)  58.0
# 416                         NaN  Long Passer (AI), Long Shot Taker (AI)  68.0
# 694   #Aerial Threat, #Strength                              Leadership  65.0
# 926                         NaN                        Long Passer (AI)  75.0
# 1146                        NaN                     Speed Dribbler (AI)  73.0
#
#       shooting  passing  dribbling  defending  physic  attacking_crossing  \
# 147       55.0     70.0       67.0       86.0    77.0                  64
# 416       76.0     72.0       72.0       75.0    81.0                  63
# 694       78.0     69.0       71.0       29.0    86.0                  61
# 926       70.0     72.0       76.0       73.0    76.0                  65
# 1146      70.0     75.0       77.0       73.0    68.0                  78
#
#       attacking_finishing  attacking_heading_accuracy  \
# 147                    45                          81
# 416                    72                          75
# 694                    81                          87
# 926                    69                          57
# 1146                   66                          57
#
#       attacking_short_passing  attacking_volleys  skill_dribbling  \
# 147                        77                 38               62
# 416                        78                 75               70
# 694                        77                 74               73
# 926                        78                 45               77
# 1146                       77                 67               78
#
#       skill_curve  ...  power_stamina  power_strength  power_long_shots  \
# 147            63  ...             76              77                58
# 416            54  ...             78              83                78
# 694            66  ...             78              94                69
# 926            58  ...             78              75                74
# 1146           79  ...             66              67                74
#
#       mentality_aggression  mentality_interceptions  mentality_positioning  \
# 147                     79                       85                     52
# 416                     80                       77                     72
# 694                     80                       30                     81
# 926                     77                       75                     68
# 1146                    74                       74                     75
#
#       mentality_vision  mentality_penalties  mentality_composure  \
# 147                 62                   58                   86
# 416                 69                   78                   80
# 694                 77                   75                   79
# 926                 74                   54                   72
# 1146                72                   72                   81
#
#       defending_marking_awareness  defending_standing_tackle  \
# 147                            87                         87
# 416                            75                         76
# 694                            25                         17
# 926                            73                         76
# 1146                           75                         74
#
#       defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 147                         84                  16                     6
# 416                         72                  15                    14
# 694                         21                  15                    12
# 926                         73                  11                     8
# 1146                        76                   6                     6
#
#       goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes  \
# 147                    14                       16                    14
# 416                     8                        6                     7
# 694                    11                       11                     8
# 926                    16                       16                    15
# 1146                   14                        7                    10
#
#       goalkeeping_speed    ls    st    rs  lw  lf  cf  rf  rw   lam   cam  \
# 147                 NaN  65+3  65+3  65+3  63  65  65  65  63  66+3  66+3
# 416                 NaN  75+3  75+3  75+3  72  74  74  74  72  74+3  74+3
# 694                 NaN    78    78    78  73  76  76  76  73  74+2  74+2
# 926                 NaN  71+2  71+2  71+2  73  74  74  74  73  75+2  75+2
# 1146                NaN  71+2  71+2  71+2  75  74  74  74  75  75+1  75+1
#
#        ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb  \
# 147   66+3  66+3  73+3  73+3  73+3  66+3  77+3  81+2  81+2  81+2  77+3  78+3
# 416   74+3  73+3  76+3  76+3  76+3  73+3  74+3  78+2  78+2  78+2  74+3  74+3
# 694   74+2  73+2  69+2  69+2  69+2  73+2  53+2  54+2  54+2  54+2  53+2  50+2
# 926   75+2  74+2  75+2  75+2  75+2  74+2  74+2  76+2  76+2  76+2  74+2  73+2
# 1146  75+1  74+2  74+2  74+2  74+2  74+2  75+1  74+2  74+2  74+2  75+1  74+2
#
#        lcb    cb   rcb    rb    gk  \
# 147   82+1  82+1  82+1  78+3  21+3
# 416   77+3  77+3  77+3  74+3  18+3
# 694   50+2  50+2  50+2  50+2  18+2
# 926   73+2  73+2  73+2  73+2  19+2
# 1146  72+2  72+2  72+2  74+2  15+2
#
#                                         player_face_url club_logo_url  \
# 147   https://cdn.sofifa.net/players/184/087/22_120.png           NaN
# 416   https://cdn.sofifa.net/players/197/242/22_120.png           NaN
# 694   https://cdn.sofifa.net/players/187/607/22_120.png           NaN
# 926   https://cdn.sofifa.net/players/200/094/22_120.png           NaN
# 1146  https://cdn.sofifa.net/players/154/950/22_120.png           NaN
#
#      club_flag_url                           nation_logo_url  \
# 147            NaN  https://cdn.sofifa.net/teams/1325/60.png
# 416            NaN  https://cdn.sofifa.net/teams/1353/60.png
# 694            NaN  https://cdn.sofifa.net/teams/1357/60.png
# 926            NaN  https://cdn.sofifa.net/teams/1357/60.png
# 1146           NaN  https://cdn.sofifa.net/teams/1357/60.png
#
#                           nation_flag_url
# 147   https://cdn.sofifa.net/flags/be.png
# 416   https://cdn.sofifa.net/flags/pl.png
# 694   https://cdn.sofifa.net/flags/ru.png
# 926   https://cdn.sofifa.net/flags/ru.png
# 1146  https://cdn.sofifa.net/flags/ru.png
#
# [5 rows x 110 columns]

# %%
# tomamos de los valores en nulo la posicion que jueva en el equipo de su nacionalidad
df_position_cruce_gen = df_position_cruce_gen[['sofifa_id','nation_position']]
df_position_cruce_gen
# Out:
#       sofifa_id nation_position
# 147      184087             RCB
# 416      197242             CDM
# 694      187607              ST
# 926      200094             RDM
# 1146     154950              LM
# 1152     167575              GK
# 1182     189060             RCB
# 1241     205211              GK
# 1255     207554              RM
# 1759     223058              RM
# 2170     219409              RB
# 2391     244700             SUB
# 2499     187533             SUB
# 2590     201884              RM
# 2601     204121             SUB
# 2854     229585             SUB
# 2903     231493             CDM
# 3169     188537              RM
# 3260     199904             SUB
# 3358     211592             RCB
# 3721     240225             SUB
# 3824     261529             SUB
# 3890     184477             SUB
# 4390     235973             SUB
# 4442     240309             SUB

# %%
#de estar en nulo la columna posicion entonces tomamos los valores de la posicion que juega en el equipo de su nacionalidad
df_skills['position'] =  df_skills.position.combine_first(df_position_cruce_gen.nation_position)
df_skills
# Out:
#       sofifa_id position  pace  shooting  passing  dribbling  defending  \
# 0        158023       RW  85.0      92.0     91.0       95.0       34.0
# 1        188545       ST  78.0      92.0     79.0       86.0       44.0
# 2         20801       ST  87.0      94.0     80.0       88.0       34.0
# 3        190871       LW  91.0      83.0     86.0       94.0       37.0
# 4        192985      RCM  76.0      86.0     93.0       88.0       64.0
# ...         ...      ...   ...       ...      ...        ...        ...
# 4588     261987      RES  61.0      56.0     67.0       66.0       62.0
# 4589     262411      SUB  67.0      64.0     70.0       72.0       68.0
# 4590     262815       RB  81.0      51.0     66.0       70.0       66.0
# 4591     263230      SUB  76.0      70.0     60.0       65.0       39.0
# 4592     263383      SUB  61.0      62.0     67.0       71.0       65.0
#
#       physic  attacking_crossing  attacking_finishing  \
# 0       65.0                  85                   95
# 1       82.0                  71                   95
# 2       75.0                  87                   95
# 3       63.0                  85                   83
# 4       78.0                  94                   82
# ...      ...                 ...                  ...
# 4588    58.0                  46                   55
# 4589    79.0                  66                   60
# 4590    67.0                  70                   61
# 4591    71.0                  64                   74
# 4592    73.0                  57                   61
#
#       attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                             70                       91                 88
# 1                             90                       85                 89
# 2                             90                       80                 86
# 3                             63                       86                 86
# 4                             55                       94                 82
# ...                          ...                      ...                ...
# 4588                          49                       75                 37
# 4589                          62                       73                 58
# 4590                          49                       71                 29
# 4591                          72                       63                 58
# 4592                          54                       70                 61
#
#       skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  \
# 0                  96           93                 94                  91
# 1                  85           79                 85                  70
# 2                  88           81                 84                  77
# 3                  95           88                 87                  81
# 4                  88           85                 83                  93
# ...               ...          ...                ...                 ...
# 4588               65           56                 65                  73
# 4589               73           73                 63                  70
# 4590               71           74                 35                  69
# 4591               66           56                 49                  57
# 4592               71           60                 49                  74
#
#       skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 0                     96                     91                     80
# 1                     88                     77                     79
# 2                     88                     85                     88
# 3                     95                     93                     89
# 4                     91                     76                     76
# ...                  ...                    ...                    ...
# 4588                  70                     63                     59
# 4589                  70                     69                     66
# 4590                  72                     80                     82
# 4591                  65                     79                     74
# 4592                  78                     59                     62
#
#       movement_agility  movement_reactions  movement_balance  \
# 0                   91                  94                95
# 1                   77                  93                82
# 2                   86                  94                74
# 3                   96                  89                84
# 4                   79                  91                78
# ...                ...                 ...               ...
# 4588                61                  68                57
# 4589                74                  69                65
# 4590                67                  58                65
# 4591                55                  70                75
# 4592                53                  71                55
#
#       power_shot_power  power_jumping  power_stamina  power_strength  \
# 0                   86             68             72              69
# 1                   90             85             76              86
# 2                   94             95             77              77
# 3                   80             64             81              53
# 4                   91             63             89              74
# ...                ...            ...            ...             ...
# 4588                52             61             69              53
# 4589                73             67             81              77
# 4590                45             69             73              70
# 4591                74             68             65              74
# 4592                62             61             78              72
#
#       power_long_shots  mentality_aggression  mentality_interceptions  \
# 0                   94                    44                       40
# 1                   87                    81                       49
# 2                   93                    63                       29
# 3                   81                    63                       37
# 4                   91                    76                       66
# ...                ...                   ...                      ...
# 4588                64                    58                       69
# 4589                65                    83                       70
# 4590                40                    50                       64
# 4591                63                    70                       30
# 4592                66                    72                       66
#
#       mentality_positioning  mentality_vision  mentality_penalties  \
# 0                        93                95                   75
# 1                        95                81                   90
# 2                        95                76                   88
# 3                        86                90                   93
# 4                        88                94                   83
# ...                     ...               ...                  ...
# 4588                     67                75                   60
# 4589                     68                70                   66
# 4590                     65                59                   40
# 4591                     73                59                   63
# 4592                     68                71                   48
#
#       mentality_composure  defending_marking_awareness  \
# 0                      96                           20
# 1                      88                           35
# 2                      95                           24
# 3                      93                           35
# 4                      89                           68
# ...                   ...                          ...
# 4588                   73                           60
# 4589                   74                           61
# 4590                   70                           68
# 4591                   59                           35
# 4592                   74                           64
#
#       defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                            35                        24                   6
# 1                            42                        19                  15
# 2                            32                        24                   7
# 3                            32                        29                   9
# 4                            65                        53                  15
# ...                         ...                       ...                 ...
# 4588                         70                        46                  11
# 4589                         74                        69                  11
# 4590                         70                        67                  12
# 4591                         38                        34                  14
# 4592                         70                        61                  13
#
#       goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                       11                   15                       14
# 1                        6                   12                        8
# 2                       11                   15                       14
# 3                        9                   15                       15
# 4                       13                    5                       10
# ...                    ...                  ...                      ...
# 4588                     7                   13                       12
# 4589                     8                    8                       15
# 4590                    12                   11                       15
# 4591                    15                   14                       12
# 4592                    10                   10                        6
#
#       goalkeeping_reflexes  goalkeeping_speed
# 0                        8                NaN
# 1                       10                NaN
# 2                       11                NaN
# 3                       11                NaN
# 4                       13                NaN
# ...                    ...                ...
# 4588                     9                NaN
# 4589                     8                NaN
# 4590                     9                NaN
# 4591                     8                NaN
# 4592                     9                NaN
#
# [4593 rows x 43 columns]

# %%
#validamos de nuevo los nulos y se observa que posiblemente sea porque algunos de estos valores 
# no lo tienen los porteros, asi como valores de porteros que no tienen el resto de los jugadores por lo que simplemente se agrega 0 a las variables numericas.
status(df_skills)
# Out:
#                        variable  q_nan     p_nan  q_zeros  p_zeros  unique  \
# 0                     sofifa_id      0  0.000000        0      0.0    4593
# 1                      position      0  0.000000        0      0.0      29
# 2                          pace    444  0.096669        0      0.0      69
# 3                      shooting    444  0.096669        0      0.0      74
# 4                       passing    444  0.096669        0      0.0      56
# 5                     dribbling    444  0.096669        0      0.0      56
# 6                     defending    444  0.096669        0      0.0      73
# 7                        physic    444  0.096669        0      0.0      54
# 8            attacking_crossing      0  0.000000        0      0.0      88
# 9           attacking_finishing      0  0.000000        0      0.0      93
# 10   attacking_heading_accuracy      0  0.000000        0      0.0      87
# 11      attacking_short_passing      0  0.000000        0      0.0      84
# 12            attacking_volleys      0  0.000000        0      0.0      87
# 13              skill_dribbling      0  0.000000        0      0.0      89
# 14                  skill_curve      0  0.000000        0      0.0      89
# 15            skill_fk_accuracy      0  0.000000        0      0.0      88
# 16           skill_long_passing      0  0.000000        0      0.0      84
# 17           skill_ball_control      0  0.000000        0      0.0      85
# 18        movement_acceleration      0  0.000000        0      0.0      79
# 19        movement_sprint_speed      0  0.000000        0      0.0      80
# 20             movement_agility      0  0.000000        0      0.0      77
# 21           movement_reactions      0  0.000000        0      0.0      45
# 22             movement_balance      0  0.000000        0      0.0      77
# 23             power_shot_power      0  0.000000        0      0.0      74
# 24                power_jumping      0  0.000000        0      0.0      67
# 25                power_stamina      0  0.000000        0      0.0      83
# 26               power_strength      0  0.000000        0      0.0      68
# 27             power_long_shots      0  0.000000        0      0.0      90
# 28         mentality_aggression      0  0.000000        0      0.0      85
# 29      mentality_interceptions      0  0.000000        0      0.0      86
# 30        mentality_positioning      0  0.000000        0      0.0      94
# 31             mentality_vision      0  0.000000        0      0.0      84
# 32          mentality_penalties      0  0.000000        0      0.0      86
# 33          mentality_composure      0  0.000000        0      0.0      76
# 34  defending_marking_awareness      0  0.000000        0      0.0      88
# 35    defending_standing_tackle      0  0.000000        0      0.0      86
# 36     defending_sliding_tackle      0  0.000000        0      0.0      86
# 37           goalkeeping_diving      0  0.000000        0      0.0      46
# 38         goalkeeping_handling      0  0.000000        0      0.0      47
# 39          goalkeeping_kicking      0  0.000000        0      0.0      58
# 40      goalkeeping_positioning      0  0.000000        0      0.0      49
# 41         goalkeeping_reflexes      0  0.000000        0      0.0      46
# 42            goalkeeping_speed   4149  0.903331        0      0.0      49
#
#        type
# 0     int64
# 1    object
# 2   float64
# 3   float64
# 4   float64
# 5   float64
# 6   float64
# 7   float64
# 8     int64
# 9     int64
# 10    int64
# 11    int64
# 12    int64
# 13    int64
# 14    int64
# 15    int64
# 16    int64
# 17    int64
# 18    int64
# 19    int64
# 20    int64
# 21    int64
# 22    int64
# 23    int64
# 24    int64
# 25    int64
# 26    int64
# 27    int64
# 28    int64
# 29    int64
# 30    int64
# 31    int64
# 32    int64
# 33    int64
# 34    int64
# 35    int64
# 36    int64
# 37    int64
# 38    int64
# 39    int64
# 40    int64
# 41    int64
# 42  float64

# %%
df_skills.fillna(0)
# Out:
#       sofifa_id position  pace  shooting  passing  dribbling  defending  \
# 0        158023       RW  85.0      92.0     91.0       95.0       34.0
# 1        188545       ST  78.0      92.0     79.0       86.0       44.0
# 2         20801       ST  87.0      94.0     80.0       88.0       34.0
# 3        190871       LW  91.0      83.0     86.0       94.0       37.0
# 4        192985      RCM  76.0      86.0     93.0       88.0       64.0
# ...         ...      ...   ...       ...      ...        ...        ...
# 4588     261987      RES  61.0      56.0     67.0       66.0       62.0
# 4589     262411      SUB  67.0      64.0     70.0       72.0       68.0
# 4590     262815       RB  81.0      51.0     66.0       70.0       66.0
# 4591     263230      SUB  76.0      70.0     60.0       65.0       39.0
# 4592     263383      SUB  61.0      62.0     67.0       71.0       65.0
#
#       physic  attacking_crossing  attacking_finishing  \
# 0       65.0                  85                   95
# 1       82.0                  71                   95
# 2       75.0                  87                   95
# 3       63.0                  85                   83
# 4       78.0                  94                   82
# ...      ...                 ...                  ...
# 4588    58.0                  46                   55
# 4589    79.0                  66                   60
# 4590    67.0                  70                   61
# 4591    71.0                  64                   74
# 4592    73.0                  57                   61
#
#       attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                             70                       91                 88
# 1                             90                       85                 89
# 2                             90                       80                 86
# 3                             63                       86                 86
# 4                             55                       94                 82
# ...                          ...                      ...                ...
# 4588                          49                       75                 37
# 4589                          62                       73                 58
# 4590                          49                       71                 29
# 4591                          72                       63                 58
# 4592                          54                       70                 61
#
#       skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  \
# 0                  96           93                 94                  91
# 1                  85           79                 85                  70
# 2                  88           81                 84                  77
# 3                  95           88                 87                  81
# 4                  88           85                 83                  93
# ...               ...          ...                ...                 ...
# 4588               65           56                 65                  73
# 4589               73           73                 63                  70
# 4590               71           74                 35                  69
# 4591               66           56                 49                  57
# 4592               71           60                 49                  74
#
#       skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 0                     96                     91                     80
# 1                     88                     77                     79
# 2                     88                     85                     88
# 3                     95                     93                     89
# 4                     91                     76                     76
# ...                  ...                    ...                    ...
# 4588                  70                     63                     59
# 4589                  70                     69                     66
# 4590                  72                     80                     82
# 4591                  65                     79                     74
# 4592                  78                     59                     62
#
#       movement_agility  movement_reactions  movement_balance  \
# 0                   91                  94                95
# 1                   77                  93                82
# 2                   86                  94                74
# 3                   96                  89                84
# 4                   79                  91                78
# ...                ...                 ...               ...
# 4588                61                  68                57
# 4589                74                  69                65
# 4590                67                  58                65
# 4591                55                  70                75
# 4592                53                  71                55
#
#       power_shot_power  power_jumping  power_stamina  power_strength  \
# 0                   86             68             72              69
# 1                   90             85             76              86
# 2                   94             95             77              77
# 3                   80             64             81              53
# 4                   91             63             89              74
# ...                ...            ...            ...             ...
# 4588                52             61             69              53
# 4589                73             67             81              77
# 4590                45             69             73              70
# 4591                74             68             65              74
# 4592                62             61             78              72
#
#       power_long_shots  mentality_aggression  mentality_interceptions  \
# 0                   94                    44                       40
# 1                   87                    81                       49
# 2                   93                    63                       29
# 3                   81                    63                       37
# 4                   91                    76                       66
# ...                ...                   ...                      ...
# 4588                64                    58                       69
# 4589                65                    83                       70
# 4590                40                    50                       64
# 4591                63                    70                       30
# 4592                66                    72                       66
#
#       mentality_positioning  mentality_vision  mentality_penalties  \
# 0                        93                95                   75
# 1                        95                81                   90
# 2                        95                76                   88
# 3                        86                90                   93
# 4                        88                94                   83
# ...                     ...               ...                  ...
# 4588                     67                75                   60
# 4589                     68                70                   66
# 4590                     65                59                   40
# 4591                     73                59                   63
# 4592                     68                71                   48
#
#       mentality_composure  defending_marking_awareness  \
# 0                      96                           20
# 1                      88                           35
# 2                      95                           24
# 3                      93                           35
# 4                      89                           68
# ...                   ...                          ...
# 4588                   73                           60
# 4589                   74                           61
# 4590                   70                           68
# 4591                   59                           35
# 4592                   74                           64
#
#       defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                            35                        24                   6
# 1                            42                        19                  15
# 2                            32                        24                   7
# 3                            32                        29                   9
# 4                            65                        53                  15
# ...                         ...                       ...                 ...
# 4588                         70                        46                  11
# 4589                         74                        69                  11
# 4590                         70                        67                  12
# 4591                         38                        34                  14
# 4592                         70                        61                  13
#
#       goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                       11                   15                       14
# 1                        6                   12                        8
# 2                       11                   15                       14
# 3                        9                   15                       15
# 4                       13                    5                       10
# ...                    ...                  ...                      ...
# 4588                     7                   13                       12
# 4589                     8                    8                       15
# 4590                    12                   11                       15
# 4591                    15                   14                       12
# 4592                    10                   10                        6
#
#       goalkeeping_reflexes  goalkeeping_speed
# 0                        8                0.0
# 1                       10                0.0
# 2                       11                0.0
# 3                       11                0.0
# 4                       13                0.0
# ...                    ...                ...
# 4588                     9                0.0
# 4589                     8                0.0
# 4590                     9                0.0
# 4591                     8                0.0
# 4592                     9                0.0
#
# [4593 rows x 43 columns]

# %% [markdown]
# **Se crea el jugador perfecto para ver a donde se ubica en nuestra visualización**

# %%
MachineGunDict={'Name':'MachineGun','Overall':99}
for skills in skills_ratings:
    MachineGunDict[skills]=99
    
df_n=df_n.append(MachineGunDict,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-4f2134342c3d> in <module>
#       3     MachineGunDict[skills]=99
#       4
# ----> 5 df_n=df_n.append(MachineGunDict,ignore_index=True)
#
# NameError: name 'df_n' is not defined

# %%
JugadorPromedioDict={'Name':'JugadorPromedio','Overall':df_n.Overall.mean()}
for skills in skills_ratings:
    JugadorPromedioDict[skills]=df_n[skills].mean()
    
df_n=df_n.append(JugadorPromedioDict,ignore_index=True)

# %%
df_skills=df_n[skills_ratings] #base, sólo con desempeños según habilidad (numéricas)

# %%
df_skills.head(4)

# %% [markdown]
# ## 3.-Exploratorio-Visual-para-Clustering

# %% [markdown]
# Visualizamos los datos (jugadores) según sus habilidades es decir, en un espacio 34 dimensional. Cómo hacemos? empecemos de a dos variables numéricas por vez
#
# **Consigna de trabajo:** visualizar a los jugadores (datos) usando las variables numéricas en skill_ratings de a pares. Emergen grupos/clusters?

# %%
skills_ratings

# %%
#data=[]
bool_crack=df_n["Overall"] > 85 #diferenciamos a los mejores jugadores

#Elejimos dos variables, para esto elegimos dos números entre 0 y  de n_skills-1
skill_1=skills_ratings[6]
skill_2=skills_ratings[10]

# %% [markdown]
# Gráfica con matplotlib.pyplot, liviana pero más sencilla

# %%
plt.figure(figsize=(8,8), dpi=80)
plt.scatter(df_skills[skill_1], y=df_skills[skill_2],s=3,c=bool_crack)
plt.xlabel(skill_1)
plt.ylabel(skill_2)
plt.show()

# %%
sns.pairplot(df_skills[skills_ratings[0:5]])

# %% [markdown]
# Gráfica con Plotly, más completa e interactiva pero un poco pesada

# %%
#Elejimos dos variables, para esto elegimos dos números entre 0 y  de n_skills-1
skill_1=skills_ratings[2]
skill_2=skills_ratings[3]

# %%
graf1 = go.Scatter(x=df_skills[skill_1], y=df_skills[skill_2],
                           mode='markers',
                        text=df_n.loc[:,'Club'], #'Height', 'Weight', 'Club', 'Age', 'Name','Position'
                           marker=dict(
                                size=5)
                           )

crack =go.Scatter(x=df_skills.loc[bool_crack,skill_1], y=df_skills.loc[bool_crack,skill_2],name='Top players',
                      text=df_n.loc[bool_crack,'Name'],
                      textfont=dict(family='sans serif',size=10,color='black'),
                      opacity=0.9,mode='text')

data=[graf1,crack]

layout = go.Layout(title="Visualización de la base de a dos variables numéricas",titlefont=dict(size=20),
                xaxis=dict(title=skill_1),
                yaxis=dict(title=skill_2),
                autosize=False, width=1000,height=650)

fig = go.Figure(data=data, layout=layout)

# %%
#En Colab
fig.show(renderer="colab")

# %%
#En Jupyter Ntb abre en otra ventana, 
plot(fig)

# %%
#en Jupyter Ntb, abre en la ntb
#iplot(fig)

# %% [markdown]
# **Consigna de trabajo:** buscar agrupamientos de jugadores de manera intuitiva por cercanía (en espacios bidimensionales, de a dos variables por vez).
#
# Que siginifica cercanía? cómo se mide? en que espacio/s están buscando?
#
# Si se encuentran, tratar de explicarlos visualmente.
#
# -----------------------------------------------------
# En próxima gráfica, similar a la anterior, también se diferencian los mejores jugadores y alguna característica/variable de interés (que pueden cambiar)
#
# Se puede ubicar también un jugador en particular. Con la siguiente linea de comando, por ejemplo, Leo Messi:

# %%
#P/Gráfico 2

#Elegimos un jugador
recherche_joueur=df_n["Name"]=='L. Messi' 
#recherche_joueur=df_n["Name"]==df_n["Name"][4000] # acá podemos elegir otro 

bool_crack=df_n["Overall"] > 85
#bool_elecc=df_n["Club"]=='FC Barcelona' 
#bool_elecc=df_n["Name"]=='JugadorPromedio'
bool_elecc=df_n["Position"]=='GK' 
bool_no_crack=df_n["Overall"]<86
bool_machinegun=df_n["Name"]=='MachineGun'

#Elegir dos números entre 0 y  de n_skills-1
skill_1=skills_ratings[6]  #6
skill_2=skills_ratings[25]  #25

# %% [markdown]
# Gráfica con plotly

# %%
palette=['navy','red','#A2D5F2','orange','green','pink']  

data=[]

n_crack =go.Scatter(x=df_skills.loc[bool_crack,skill_1], y=df_skills.loc[bool_crack,skill_2],name='Crack',
                      text=df_n.loc[bool_crack,'Name'],
                      textfont=dict(family='sans serif',size=15,color='black'),
                      opacity=0.9,marker=dict(color=palette[2],size=7),mode='markers+text')

n_no_crack =go.Scatter(x=df_skills.loc[bool_no_crack,skill_1], y=df_skills.loc[bool_no_crack,skill_2],name='Average players',
                         text=df_n.loc[bool_no_crack,'Name'],
                         opacity=0.6,marker=dict(color=palette[1],size=3),mode='markers')
n_elecc=go.Scatter(x=df_skills.loc[bool_elecc,skill_1], y=df_skills.loc[bool_elecc,skill_2],name='Elección',
                         text=df_n.loc[bool_elecc,'Name'],
                         opacity=0.9,marker=dict(color=palette[0],size=5),mode='markers')

n_machinegun =go.Scatter(x=df_skills.loc[bool_machinegun,skill_1], y=df_skills.loc[bool_machinegun,skill_2],name='Perfect player',
                           textfont=dict(family='sans serif',size=20,color='black'),
                           opacity=0.6,marker=dict(color=palette[3],size=30),mode='markers+text')


joueur_recherche =go.Scatter(x=df_skills.loc[recherche_joueur,skill_1], y=df_skills.loc[recherche_joueur,skill_2],name='Searched player',
                           text=df_n.loc[recherche_joueur,'Name'],
                            textfont=dict(family='sans serif',size=20,color='black'),
                           opacity=1,marker=dict(color=palette[4],size=40),mode='markers+text')

data=[n_no_crack,n_elecc
      ,n_crack,n_machinegun,joueur_recherche]

layout = go.Layout(title="Fifa Players",titlefont=dict(size=20),
                xaxis=dict(title=skill_1),
                yaxis=dict(title=skill_2),
                autosize=False, width=1000,height=650)

fig = go.Figure(data=data, layout=layout)

# %%
#En Colab
fig.show(renderer="colab")

# %%
#En Jupyter ntb
plot(fig) #abre y muestra en otra pestaña
#iplot(fig)  #muestra aquí

# %% [markdown]
# **Identifiquemos algunos jugadores por nombre**

# %%
print(df_n.loc[0:43,"Name"])
